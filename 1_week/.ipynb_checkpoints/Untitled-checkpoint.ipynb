# %% [markdown]
# # Exploratory Data Analysis
#
# ## 데이터셋 출처
# * [Pima Indians Diabetes Database | Kaggle](https://www.kaggle.com/uciml/pima-indians-diabetes-database)
#
# ### 데이터 구성
#
# * Pregnancies : 임신 횟수
# * Glucose : 2시간 동안의 경구 포도당 내성 검사에서 혈장 포도당 농도
# * BloodPressure : 이완기 혈압 (mm Hg)
# * SkinThickness : 삼두근 피부 주름 두께 (mm), 체지방을 추정하는데 사용되는 값
# * Insulin : 2시간 혈청 인슐린 (mu U / ml)
# * BMI : 체질량 지수 (체중kg / 키(m)^2)
# * DiabetesPedigreeFunction : 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 768개 중에 268개의 결과 클래스 변수(0 또는 1)는 1이고 나머지는 0입니다.

# %% [markdown]
# # 데이터셋 미리보기

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../data/diabetes.csv')
df.shape
# Out:
# (768, 9)

# %%
# 위에서부터 5개만 미리보기

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# info로 데이터타입, 결측치, 메모리 사용량 등의 정보를 본다

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 결측치를 봅니다

df_null = df.isnull()
df_null
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
# 결측치 갯수를 알 수 있음

df_null.sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 수치데이터에 대한 요약

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# - max값이 커서 mean이 중위값(50%)보다 크다
# - Pregnancies ~ BMI 전부 다 min == 0
# - 하지만 Glucose의 일사분위값(25%)가 99인데 min이 0이라는 것은 아마 결측치가 아닐까
# - BloodPressure, Skin Thickness, BMI도 0이 될 수 없는데 min이 0이라는 것은 아마 결측치이지 않을까

# %%
# 가장 마지막에 있는 Outcome은 label 값이기 때문에 제외하고
# 학습과 예측에 사용할 컬럼을 만들어 준다.
# feature_columns라는 변수에 담는다.

feature_columns = df.columns[:-1].tolist()
feature_columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %% [markdown]
# # 결측치 시각화

# %% [markdown]
# 값을 요약해보면 최솟값이 0으로 나오는 값들이 있음.
#
# 0이 나올 수 있는 것도 있지만 인슐린이나 혈압 등의 값은 0이 나올 수 없는 값이기 때문에 결측치라고 볼 수 있음.
#
# 따라서 0인 값을 결측치로 처리하고 시각화 해보기

# %%
cols = feature_columns[1:]
cols
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
# 결측치 여부를 나타내는 데이터프레임을 만든다.
# 0값을 결측치라 가정하고 정답(label, target)값을 제외한 칼럼에 대해 결측치 여부를 구해서 df_null이라는 데이터프레임에 담는다.

df_null = df[cols].replace(0, np.nan)
df_null = df_null.isnull()
df_null.sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %% [markdown]
# 앞에서 생성한 Decision Tree에서 Insulin이 당뇨병에 그닥 큰 영향이 없었던 이유가 결측치 때문이라고 볼 수 있음.

# %%
# 결측치 비율

df_null.mean()*100
# Out:
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %%
# 결측치 갯수를 막대그래프로 시각화

df_null.sum().plot.barh()
# Out:
# <AxesSubplot:>

# %%
# 결측치를 heatmap으로 시각화

plt.figure(figsize=(15,5))
sns.heatmap(df_null, cmap='Greys')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1 = 결측치 = True
#
# 0 = 결측치X = False

# %% [markdown]
# # 정답값
#
# - target, label 이라고 부르기도 한다.

# %%
# 정답값인 Outcome의 갯수

df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 0: 당뇨병 발병 X
#
# 1: 당뇨병 발병 O

# %%
# 정답값인 Outcome의 비율

df["Outcome"].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
# 다른 변수와 함께 보기
# 임신횟수와 정답값을 비교해보기
# "Pregnancies"를 groupby로 그룹화 하여 Outcome에 대한 비율을 구한다.
# 결과를 df_po라는 변수에 저장

df.groupby(["Pregnancies"])["Outcome"].mean()
# Out:
# Pregnancies
# 0     0.342342
# 1     0.214815
# 2     0.184466
# 3     0.360000
# 4     0.338235
# 5     0.368421
# 6     0.320000
# 7     0.555556
# 8     0.578947
# 9     0.642857
# 10    0.416667
# 11    0.636364
# 12    0.444444
# 13    0.500000
# 14    1.000000
# 15    1.000000
# 17    1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# 임신 횟수가 늘어갈수록 당뇨병 발병 확률이 올라간다.

# %%
# 발병비율과 평균값을 함게 본다.
# 여러 인자를 넣어줄 때 aggregation 함수를 사용한다.
# 인덱스로 지정되어 있던 Pregnancies를 reset_index()를 사용해 컬럼값으로 변경시켜준다.

df_po = df.groupby(["Pregnancies"])["Outcome"].agg(["mean", "count"]).reset_index()
df_po
# Out:
#     Pregnancies      mean  count
# 0             0  0.342342    111
# 1             1  0.214815    135
# 2             2  0.184466    103
# 3             3  0.360000     75
# 4             4  0.338235     68
# 5             5  0.368421     57
# 6             6  0.320000     50
# 7             7  0.555556     45
# 8             8  0.578947     38
# 9             9  0.642857     28
# 10           10  0.416667     24
# 11           11  0.636364     11
# 12           12  0.444444      9
# 13           13  0.500000     10
# 14           14  1.000000      2
# 15           15  1.000000      1
# 16           17  1.000000      1

# %%
# 임신횟수에 따른 당뇨병 발병 비율 시각화

df_po.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 서로 수의 단위가 너무 달라서 같이 표현하기엔 적합하지 않음.

# %%
df_po["mean"].plot()
# Out:
# <AxesSubplot:>

# %%
df_po["mean"].plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # countplot
#
# - 변수가 하나인 categorical한 범주형 데이터를 시각화 할 때

# %%
# 위에서 구했던 당뇨병 발병 비율을 구해본다.
# 당뇨병 발병 빈도수를 비교한다.

sns.countplot(data=df, x="Outcome")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
# 임신횟수에 따른 당뇨병 발병 빈도수를 비교한다.
# hue: Outcome 값에 따라서 색상이 다르게 나오게 한다. Outcome값이 비교 기준이 됨

sns.countplot(data=df, x="Pregnancies", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %% [markdown]
# Pregnancies가 증가할수록 조건이 많아지기 때문에 case가 적은 건에 대해서는 overfitting이 발생할 수 있음.
#
# 이럴 경우엔 범주화 해서 표현 하기도 함. ==> one-hot encoding
#
# ex) 특정 임신 횟수를 기준으로 이상/이하로 나눈다

# %%
# 임신횟수의 많고 적음에 따라 Pregnancies_high 변수를 만든다.
# 0~6: False, 7~: True

df["Pregnancies_high"] = df["Pregnancies"] > 6
df[["Pregnancies", "Pregnancies_high"]].head()
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %%
# Pregnancies_high 변수의 빈도수를 countplot으로 그리고
# Outcome 값에 따라 다른 색상으로 표현한다.

sns.countplot(data=df, x="Pregnancies_high", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies_high', ylabel='count'>

# %% [markdown]
# # barplot

# %%
# 당뇨병 발병에 따른 BMI 수치 비교

sns.barplot(data=df, x="Outcome", y="BMI")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %%
# 당뇨병 발병에 따른 포도당(Glucose) 수치 비교

sns.barplot(data=df, x="Outcome", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
# Insulin 수치가 0 이상인 관측치에 대해서 당뇨병 발병 비교

sns.barplot(data=df, x="Outcome", y="Insulin")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %% [markdown]
# y축: 평균값
#
# barplot 중간에 검은색 막대(bootstrap): 데이터 일부를 샘플링 해서 그 데이터의 95%의 신뢰구간(ci=95)

# %%
# 임신횟수에 대해 당뇨병 발병 비율 비교

sns.barplot(data=df, x="Pregnancies", y="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %%
# 임신횟수(Pregnancies)에 따른 포도당(Glucose) 수치를 당뇨병 발병여부(Outcome)에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="Glucose", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Glucose'>

# %%
# 임신 횟수(Pregnancies)에 따른 체질량지수(BMI)를 당뇨병 발병여부(Outcome)에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="BMI", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='BMI'>

# %%
# 임신횟수(Pregnancies)에 따른 인슐린 수치(Insulin)를 당뇨병 발병여부(Outcome)에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %%
# 임신횟수(Pregnancies)에 따른 인슐린 수치(Insulin)를 당뇨병 발병여부(Outcome)에 따라 시각화
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그린다.

sns.barplot(data=df[df["Insulin"]>0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# 당뇨병이 발병하는 사람들(Outcome=1)의 인슐린 수치의 신뢰구간이 차이가 많이 남
#
# 발병하지 않는 사람들(Outcome=0)은 확연하게 인슐린 수치가 낮다.

# %% [markdown]
# # boxplot

# %%
# 임신횟수(Pregnancies)에 따른 인슐린 수치(Insulin)를 당뇨병 발병여부(Outcome)에 따라 시각화

sns.boxplot(data=df, x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# boxplot은 1사분위와 3사분위 값의 범위를 나타냄
#
# 현재 이 그래프에서는
#
# 1사분위와 3사분위 값의 차이가 크고, 최솟값과 최대값 차이도 큼
# boxplot이 아래로 주저앉아있는 이유: 인슐린 값이 0인 값이 많아서

# %%
# 임신횟수(Pregnancies)에 따른 인슐린 수치(Insulin)를 당뇨병 발병여부(Outcome)에 따라 시각화
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그린다.

sns.boxplot(data=df[df["Insulin"]>0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# 당뇨병 발병 하는 사람들이 대체적으로 인슐린 수치가 높고
# 임신횟수가 늘어갈수록 수치의 차이가 크다

# %% [markdown]
# # violinplot

# %%
# 위의 그래프를 violinplot으로 시각화 한다.
# boxplot을 좀 더 자세히 표현 // boxplot은 상자 안을 자세히 알 수 없다.
# split=True : Outcome에 따라 그래프를 두 개로 나눈다

plt.figure(figsize=(15,5))
sns.violinplot(data=df[df["Insulin"]>0], x="Pregnancies", y="Insulin", hue="Outcome", split=True)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# # swarmplot

# %%
# 위의 그래프를 swarmplot으로 시각화
# 임신횟수가 증가할수록 데이터의 갯수가 줄어든다는 사실을 알 수 있음

plt.figure(figsize=(25,5))
sns.swarmplot(data=df[df["Insulin"]>0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# # distplot
#
# - 연속된 수치형 데이터를 시각화 할 때 사용
# - 히스토그램과 밀도추정곡선을 나타냄
# - 범주형 컬럼으로 만들어주고싶을 때, 어떤 값을 기준으로 나누는게 좋을지 알 수 있음
#
#
# - a: 판다스의 시리즈 형태
# - bins: 히스토그램의 막대 갯수
# - hist, kde: histogram, kde를 표현 할 건지
# - rug: 데이터의 빈도를 표시 할건지

# %%
# 당뇨병이 발병하지 않은 케이스만 모아서 subset을 만든다

df_0 = df[df["Outcome"] == 0]
df_1 = df[df["Outcome"] == 1]

df_0.shape, df_1.shape
# Out:
# ((500, 10), (268, 10))

# %%
# 임신횟수에 따른 당뇨병 발병 여부를 시각화

sns.distplot(df_0["Pregnancies"])
sns.distplot(df_1["Pregnancies"])
# Out:
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
# - Pregnancies가 5 미만인 경우, 당뇨병 발병 확률이 발병하지 않을 확률보다 적어짐
# - Pregnancies가 5 이상인 경우, 당뇨병 발병 확률이 발병하지 않을 확률보다 높아짐

# %%
# 나이에 따른 당뇨병 발병 여부를 시각화

sns.distplot(df["Age"])
# Out:
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# - 나이가 많은 케이스 보다는 20~30대에 발병 확률이 높음

# %%
# 여기서 hist=False 옵션을 주면, 선 그래프만 남게 된다.
# rug=True 하게 되면 데이터의 빈도를 표시

sns.distplot(df_0["Age"], hist=False, rug=True, label="0")
sns.distplot(df_1["Age"], hist=False, rug=True, label="1")
plt.legend()
# Out:
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - 20~30대: 당뇨병 발병 확률 > 발병하지 않을 확률
# - 30~: 당뇨병 발병 확률 < 발병하지 않을 확률

# %% [markdown]
# # Subplots

# %% [markdown]
# ## Pandas를 통한 histplot 그리기
#
# - pandas를 사용하면 모든 변수에 대한 서브플롯을 한 번에 그려준다.

# %%
# Pregnanciees_high 컬럼의 값이 Boolean값이기 때문에 int로 타입을 전환 후 histogram을 그린다.
# bins로 막대 갯수를 조정할 수 있다.
# y축 = 빈도수

df["Pregnancies_high"] = df["Pregnancies_high"].astype(int)

h = df.hist(figsize=(15,15), bins=20)

# %% [markdown]
# # 반복문을 통한 서브플롯 그리기

# %% [markdown]
# ## distplot

# %%
# 컬럼의 수 만큼 for문을 만들어서 서브플롯으로 시각화

col_num = df.columns.shape
cols = df.columns[:-1].tolist()
cols
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# distplot으로 서브플롯을 그린다.
# ax=axes[][]로 그래프 위치 지정

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15,15))

sns.distplot(df["Outcome"], ax=axes[1][2])
# Out:
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Outcome', ylabel='Density'>

# %%
# y축 = 적분했을 때 총 합이 1이 되는 값
# 밀도함수 곡선도 있음
# enumerate는 반복 횟수와 컬럼 이름을 같이 반환
# //: 나눗셈 결과에서 소수점을 제외
# %: 나머지 값

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15,15))
for i, col_name in enumerate(cols):
    row = i // 3
    col = i % 3
    print(i, col_name, row, col)
    sns.distplot(df[col_name], ax=axes[row][col])
# Out:
# 0 Pregnancies 0 0
# 1 Glucose 0 1
# 2 BloodPressure 0 2
# 3 SkinThickness 1 0
# 4 Insulin 1 1
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 5 BMI 1 2
# 6 DiabetesPedigreeFunction 2 0
# 7 Age 2 1
# 8 Outcome 2 2
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Pregnancies_high
# 1                       0.351   31        0             False
# 3                       0.167   21        0             False
# 5                       0.201   30        0             False
# 7                       0.134   29        0              True
# 10                      0.191   30        0             False
# ..                        ...  ...      ...               ...
# 762                     0.142   33        0              True
# 763                     0.171   63        0              True
# 764                     0.340   27        0             False
# 765                     0.245   30        0             False
# 767                     0.315   23        0             False
#
# [500 rows x 10 columns]

# %%
# 모든 변수에 대한 distplot을 그린다.

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15,15))
for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
#     print(i, col_name, row, col)
    sns.distplot(df_0[col_name], ax=axes[row][col])
    sns.distplot(df_1[col_name], ax=axes[row][col])
# Out:
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/angelayoon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## violinplot

# %%
# violinplot으로 서브플롯 그리기

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15,15))
for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
#     print(i, col_name, row, col)
    sns.violinplot(data=df, x="Outcome", y=col_name, ax=axes[row][col])

# %% [markdown]
# SkinThickness, BMI와 같이 0이 나올 수 없는 값인데 0에 값이 있는 것 -> 결측치

# %% [markdown]
# ## Implot
#
# - 상관계수가 높을 것 같은 두 변수에 대해 시각화 합니다.

# %%
# Glucose와 Insuline을 Outcome으로 구분하기

sns.regplot(data=df, x="Glucose", y="Insulin")
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Insulin'>

# %%
# hue="Outcome"을 지정해서 Outcome을 기준으로 한 결과를 보고싶으면 regplot이 아닌 lmplot을 사용
# regplot은 다른 색상을 지원하지 않음

sns.lmplot(data=df, x="Glucose", y="Insulin", hue="Outcome")

# %%
# Insulin 수치가 0 이상인 데이터로만 그리기

sns.lmplot(data=df[df["Insulin"] > 0], x="Glucose", y="Insulin", hue="Outcome")

# %% [markdown]
# ## pairplot
#
# - 전체적인 수치데이터에 대한 분포를 볼 때 사용
# - 변수간의 상관관계 등을 파악하기 좋음

# %%
# 모든 변수에 대해 plot을 그림
# 기본적으로 kind='scatter'로 되어 있음. 다른 그래프도 그릴 수 있다

sns.pairplot(df, kind="reg")

# %%
# PairGrid를 통해 모든 변수에 대해 Outcome에 따른 scatterplot을 그린다.

g = sns.PairGrid(df, hue="Outcome")
g.map(plt.scatter)

# %% [markdown]
# # 상관 분석 (Correlation analysis)
#
# - https://ko.wikipedia.org/wiki/상관_분석
# - 상관 분석: 두 변수간에 어떤 선형적/비선형적 관계를 갖고 있는지를 분석하는 방법
# - 두 변수는 서로 독립적인 관계이거나 상관된 관계일 수 있으며, 이 때 두 변수간의 관계의 강도를 상관관계(Correlation, Correlation coefficient)라고 한다.
# - 상관 계수(Correlation coefficient)는 두 변수간의 연관된 정도를 나타낼 뿐, 인과관계를 설명하는 것은 아님.
# - 두 변수간에 인과관계에 대한 것은 회귀분석을 통해 알 수 있다.
#
#
# - -1.0 < r < -0.7 : 강한 음적 선형관계
# - -0.7 < r < -0.3 : 뚜렷한 음적 선형관계
# - -0.3 < r < -0.1 : 약한 음적 선형관계
# - -0.1 < r < +0.1 : 거의 무시될 수 있는 선형관계
# - +1.0 < r < +0.3 : 약한 양적 선형관계
# - +0.3 < r < +0.7 : 뚜렷한 양적 선형관계
# - +0.7 < r < +1.0 : 강한 양적 선형관계

# %%
# Pregnancies ~ Age 와 Outcome행만 본다 (Pregnancies_high 제외)
# 0인 결측치는 nan으로

df_matrix = df.iloc[:,:-2].replace(0, np.nan)
df_matrix["Outcome"] = df["Outcome"]
df_matrix.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 정답 값인 Outcome을 제외하고 feature로 사용할 컬럼들에 대해 0을 결측치로 만들어 준다.
# 상관계수를 구한다.

df_corr = df_matrix.corr()
df_corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_05209_row0_col0, #T_05209_row1_col1, #T_05209_row2_col2, #T_05209_row3_col3, #T_05209_row4_col4, #T_05209_row5_col5, #T_05209_row6_col6, #T_05209_row7_col7, #T_05209_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_05209_row0_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_05209_row0_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_05209_row0_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_05209_row0_col4, #T_05209_row6_col8 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_05209_row0_col5, #T_05209_row2_col1, #T_05209_row3_col1, #T_05209_row4_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_05209_row0_col6, #T_05209_row2_col4, #T_05209_row2_col6, #T_05209_row2_col8, #T_05209_row5_col7, #T_05209_row6_col0, #T_05209_row6_col1, #T_05209_row6_col2, #T_05209_row6_col3, #T_05209_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_05209_row0_col7, #T_05209_row1_col4 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_05209_row0_col8, #T_05209_row3_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_05209_row1_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_05209_row1_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_05209_row1_col3, #T_05209_row2_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_05209_row1_col5, #T_05209_row4_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_05209_row1_col6, #T_05209_row5_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_05209_row1_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_05209_row1_col8 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_05209_row2_col0, #T_05209_row5_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_05209_row2_col5, #T_05209_row8_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_05209_row2_col7 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_05209_row3_col0, #T_05209_row5_col8, #T_05209_row8_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_05209_row3_col2, #T_05209_row8_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_05209_row3_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_05209_row3_col5 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_05209_row3_col7, #T_05209_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_05209_row3_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_05209_row4_col0, #T_05209_row5_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_05209_row4_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_05209_row4_col3, #T_05209_row7_col8 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_05209_row4_col6, #T_05209_row5_col0, #T_05209_row6_col5, #T_05209_row7_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_05209_row4_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_05209_row4_col8, #T_05209_row5_col6, #T_05209_row8_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_05209_row5_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_05209_row6_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_05209_row6_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_05209_row7_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_05209_row7_col2 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_05209_row7_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_05209_row7_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_05209_row8_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_05209_row8_col5 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_05209_row8_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_05209_row8_col7 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# </style>
# <table id="T_05209">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05209_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_05209_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_05209_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_05209_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_05209_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_05209_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_05209_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_05209_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_05209_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05209_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_05209_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_05209_row0_col1" class="data row0 col1" >0.166329</td>
#       <td id="T_05209_row0_col2" class="data row0 col2" >0.285013</td>
#       <td id="T_05209_row0_col3" class="data row0 col3" >0.167298</td>
#       <td id="T_05209_row0_col4" class="data row0 col4" >0.104081</td>
#       <td id="T_05209_row0_col5" class="data row0 col5" >0.128207</td>
#       <td id="T_05209_row0_col6" class="data row0 col6" >-0.006459</td>
#       <td id="T_05209_row0_col7" class="data row0 col7" >0.550525</td>
#       <td id="T_05209_row0_col8" class="data row0 col8" >0.268218</td>
#     </tr>
#     <tr>
#       <th id="T_05209_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_05209_row1_col0" class="data row1 col0" >0.166329</td>
#       <td id="T_05209_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_05209_row1_col2" class="data row1 col2" >0.223192</td>
#       <td id="T_05209_row1_col3" class="data row1 col3" >0.228043</td>
#       <td id="T_05209_row1_col4" class="data row1 col4" >0.581186</td>
#       <td id="T_05209_row1_col5" class="data row1 col5" >0.232771</td>
#       <td id="T_05209_row1_col6" class="data row1 col6" >0.137246</td>
#       <td id="T_05209_row1_col7" class="data row1 col7" >0.267136</td>
#       <td id="T_05209_row1_col8" class="data row1 col8" >0.494650</td>
#     </tr>
#     <tr>
#       <th id="T_05209_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_05209_row2_col0" class="data row2 col0" >0.285013</td>
#       <td id="T_05209_row2_col1" class="data row2 col1" >0.223192</td>
#       <td id="T_05209_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_05209_row2_col3" class="data row2 col3" >0.226839</td>
#       <td id="T_05209_row2_col4" class="data row2 col4" >0.098272</td>
#       <td id="T_05209_row2_col5" class="data row2 col5" >0.289230</td>
#       <td id="T_05209_row2_col6" class="data row2 col6" >-0.002805</td>
#       <td id="T_05209_row2_col7" class="data row2 col7" >0.330107</td>
#       <td id="T_05209_row2_col8" class="data row2 col8" >0.170589</td>
#     </tr>
#     <tr>
#       <th id="T_05209_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_05209_row3_col0" class="data row3 col0" >0.167298</td>
#       <td id="T_05209_row3_col1" class="data row3 col1" >0.228043</td>
#       <td id="T_05209_row3_col2" class="data row3 col2" >0.226839</td>
#       <td id="T_05209_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_05209_row3_col4" class="data row3 col4" >0.184888</td>
#       <td id="T_05209_row3_col5" class="data row3 col5" >0.648214</td>
#       <td id="T_05209_row3_col6" class="data row3 col6" >0.115016</td>
#       <td id="T_05209_row3_col7" class="data row3 col7" >0.166816</td>
#       <td id="T_05209_row3_col8" class="data row3 col8" >0.259491</td>
#     </tr>
#     <tr>
#       <th id="T_05209_level0_row4" class="row_heading level0 row4" >Insulin</th>
#       <td id="T_05209_row4_col0" class="data row4 col0" >0.104081</td>
#       <td id="T_05209_row4_col1" class="data row4 col1" >0.581186</td>
#       <td id="T_05209_row4_col2" class="data row4 col2" >0.098272</td>
#       <td id="T_05209_row4_col3" class="data row4 col3" >0.184888</td>
#       <td id="T_05209_row4_col

# %%
# 위에서 구한 상관계수를 heatmap으로 시각화 한다.
# -1 ~ +1 사이로 보기

plt.figure(figsize=(15,8))
sns.heatmap(df_corr, annot=True, vmax=1, vmin=-1, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
# Outcome 수치에 대한 상관계수만 모아서 본다.

df_corr["Outcome"]
# Out:
# Pregnancies                 0.268218
# Glucose                     0.494650
# BloodPressure               0.170589
# SkinThickness               0.259491
# Insulin                     0.303454
# BMI                         0.313680
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# # 상관관계가 높은 변수끼리 보기

# %%
# 결측치를 처리한 데이터프레임으로 Insulin과 Glucose의 regplot 그리기

sns.regplot(data=df_matrix, x="Insulin", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %% [markdown]
# - 회귀선의 기울기가 1에 가까울수록 상관관계가 높다.
# - 인슐린이 높은 곳에 Outlier들이 발견된다.

# %%
# 결측치를 처리한 데이터로 할지, 원래 데이터로 할지 정해야 함
# Age와 Pregnancies로 regplot 그리기

sns.regplot(data=df, x="Age", y="Pregnancies")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pregnancies'>

# %%
# Age 와 Pregnanciesfh lmplot을 그리고 Outcome에 따라 다른 색상으로 나타내기
# Outcome값에 따라 다른 그래프에 표시하고싶은 경우, col="Outcome"

sns.lmplot(data=df, x="Age", y="Pregnancies", hue="Outcome", col="Outcome")
